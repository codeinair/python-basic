# %% [markdown]
# Seaborn
#
# Seaborn is not available by default in Anaconda so we need to import it using below command by running it in anaconda cmd prompt
# conda install seaborn

# %%
import seaborn as sea
# %matplotlib inline

# %%
import pandas as pd
heartData = pd.read_csv("D:\\Personal\\Study\\Bits Pilani\\Git\\python-basic-1\\Datasets\\heart.csv")
heartData.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
sea.distplot(heartData["chol"])

# %%
sea.distplot(heartData["chol"],bins=20)

# %%
sea.jointplot(x="trestbps",y="chol",data=heartData)
